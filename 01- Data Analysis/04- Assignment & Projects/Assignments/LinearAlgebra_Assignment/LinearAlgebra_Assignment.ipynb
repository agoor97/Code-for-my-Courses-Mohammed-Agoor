# %% [markdown]
# ### Write your answer for each Question in the Cell below the Question or solve in a paper and upload your solution as an Image

# %% [markdown]
# #### `Q1: Calculate the Norm1 & Norm2 for the following Vectors`
#
# $$vect_1 = [1, 5, 6, 7]$$
# $$vect_2 = [3, 6, 7, 9]$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ------

# %% [markdown]
# #### `Q2: Calculate the Inner/Dot product of the following two Vectors `
#
# $$vect_1 = [1, 5, 6, 7]$$
# $$vect_2 = [3, 6, 7, 9]$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# --------------

# %% [markdown]
# #### `Q3: Calculate the angle between the following two Vectors `
#
# $$vect_1 = [1, 5, 6, 7]$$
# $$vect_2 = [3, 6, 7, 9]$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ------

# %% [markdown]
# #### `Q4: For each following vector, write to which space it belongs to `
#
# $$vect_1 = [1, 5, 6, 7]$$
# $$vect_2 = [3, 6, 7]$$
# $$vect_3 = [5, 8, 9, 10, 11, 12, 15, 20]$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ---

# %% [markdown]
# #### `Q5: Calculate A.B (matrices multilpication) `
#
# $$A_{(3x3)} = \begin{bmatrix} 1 & 2 & 1 \\ 3 & 0 & 1 \\ 0 & 2 & 4 \end{bmatrix}$$
# $$B_{(3x2)} = \begin{bmatrix} 4 & 2  \\ 1 & 4  \\ 0 & 3 \end{bmatrix}$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ----

# %% [markdown]
# #### `Q6: What is the number of independent vectors needed for 2D space to span the Whole space `
# #### `Q7: What is the number of independent vectors needed for 3D space to span the Whole space `

# %% [markdown]
# #### Your Solution

# %% [markdown]
# --------

# %% [markdown]
# #### `Q8: If we are in 3D space and we have two vectors not pointing in the same direction `
# #### `(independent),Does these two vectors span the whole space, if not . what space they span?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# -----

# %% [markdown]
# #### `Q9: What is the properties of basis of space & what is the best basis of 3D Space? `

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ------

# %% [markdown]
# #### `Q10: Write some of Linear Transformation Techniques?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# -----

# %% [markdown]
# #### `Q11: Can Determinant be Zero or Negative value, if yes . explain your answer ?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ----

# %% [markdown]
# #### `Q12: Calculate the Determinant of the following two matrices`
#
# $$mat1_{(2x2)} = \begin{bmatrix} 1 & 2 \\ 3 & 5 \end{bmatrix}$$
# $$mat2_{(2x2)} = \begin{bmatrix} 4 & 2  \\ 7 & 4 \end{bmatrix}$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ---

# %% [markdown]
# #### `Q13: The Transformation Can't be undone and there is no inverse if the determinant=zero, why?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# -----

# %% [markdown]
# #### `Q14: What do you know about rank and full rank matrix ?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# -----

# %% [markdown]
# #### `Q15: Calculate the Invers of the following two matrices ?`
#
# $$mat1_{(2x2)} = \begin{bmatrix} 3 & 4 \\ 2 & 5 \end{bmatrix}$$
# $$mat2_{(2x2)} = \begin{bmatrix} 5 & 6  \\ 1 & 4 \end{bmatrix}$$

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ---

# %% [markdown]
# #### `Q16: What do you know about singular matrix ?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# -----

# %% [markdown]
# #### `Q17: What do you know about Eigen Values & Eigen Vectors ?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ----

# %% [markdown]
# #### `Q18: Does eigen values & eigen vectors important, if yes why?`

# %% [markdown]
# #### Your Solution

# %% [markdown]
# ----

# %% [markdown]
# ### Hope you best of luck
# ![603e6f6e60bfe6a04f06ebab_Thankyou.png](attachment:603e6f6e60bfe6a04f06ebab_Thankyou.png)
